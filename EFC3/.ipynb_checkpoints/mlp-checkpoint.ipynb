# %%
import math
import sys
import os

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.io as sio

from pandas.plotting import scatter_matrix
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, f1_score, roc_curve, roc_auc_score, classification_report
from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import KernelPCA

from keras.models import Sequential
from keras.regularizers import l1_l2
from keras.utils import np_utils
from keras.layers.core import Dense, Activation, Dropout
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
def plot_roc(df_test_out, preds):
    # Results ROC
    fpr, tpr, thresholds = roc_curve(df_test_out, preds)
    roc_score = roc_auc_score(df_test_out, preds)
    fig = plt.figure(figsize=(10,5))
    plt.grid(color='#919191', linestyle=':', linewidth=1)
    plt.plot(fpr, tpr, label='MPL')
    plt.plot([0, 1], [0, 1], color='red', lw=1, linestyle='--', label='Decisão aleatória')
    plt.title('Curva ROC')
    plt.xlabel('FP')
    plt.ylabel('TP')
    plt.xlim([-0.05, 1.0])
    plt.ylim([-0.05, 1.05])
    plt.grid(True)
    plt.legend()
    plt.show()
    fig.savefig('mlp_roc.png', dpi=600)
    print("ROC Score", roc_score)

# %%
def plot_history(history):
    # plot training history
    fig = plt.figure(figsize=(10,5))
    plt.grid(color='#919191', linestyle=':', linewidth=1)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.grid(True)
    plt.legend()
    fig.savefig('mlp_history.png', dpi=600)
    plt.show()

# %%
# Read and build DataFrames
df_test = sio.loadmat('dados_teste.mat')
df_train = sio.loadmat('dados_treinamento.mat')
df_val = sio.loadmat('dados_val.mat')

df_test = pd.DataFrame(np.concatenate((df_test['Xt'], df_test['yt']), axis=1),columns=['x1', 'x2', 'y'])
df_train = pd.DataFrame(np.concatenate((df_train['X'], df_train['y']), axis=1),columns=['x1', 'x2', 'y'])
df_val = pd.DataFrame(np.concatenate((df_val['Xval'], df_val['yval']), axis=1),columns=['x1', 'x2', 'y'])

# Data normalization and encoding
scaler = StandardScaler()
df_train_out = df_train.loc[:,'y'].replace(-1, 0)
df_train_inp = df_train.drop('y', axis=1)
scaler.fit(df_train_inp) 

df_train_inp_scaled = pd.DataFrame(scaler.transform(df_train_inp), columns=['x1','x2'])

df_val_out = df_val.loc[:,'y'].replace(-1, 0)
df_val_inp = df_val.drop('y', axis=1)
df_val_inp_scaled = pd.DataFrame(scaler.transform(df_val_inp), columns=['x1','x2'])


df_test_out = df_test.loc[:,'y'].replace(-1, 0)
df_test_inp = df_test.drop('y', axis=1)
df_test_inp_scaled = pd.DataFrame(scaler.transform(df_test_inp), columns=['x1','x2'])

# %%
# transformer = KernelPCA(n_components=2, kernel='linear')
# transformer.fit(df_train_inp)
# df_train_inp_kpca = pd.DataFrame(transformer.transform(df_train_inp))
# print(df_train_inp.corr())
# print(df_train_inp_kpca.corr())

# %%
fig = plt.figure(figsize=(10,5))
plt.grid(color='#919191', linestyle=':', linewidth=1)
plt.scatter(df_train_inp['x1'],df_train_inp['x2'], label='Original')
plt.scatter(df_train_inp_scaled['x1'],df_train_inp_scaled['x2'], label='Scaled') 
plt.grid(True)
plt.legend()
fig.savefig('mlp_inp_scaled.png', dpi=600)
plt.show()
df_train_out.hist()
plt.savefig('mlp_out_scaled.png', dpi=600)

# %%
# MLP
neuron_num = 35
mlp_weight = 'mlp_weight_ne'+str(neuron_num)
callbacks = [
    EarlyStopping(monitor='val_loss', \
        min_delta=0.01, patience=200, verbose=1,\
        mode='min', baseline=0.001, restore_best_weights=False),
    ModelCheckpoint(mlp_weight, monitor='val_loss', save_best_only=True, verbose=1)
]
model = Sequential()
# model.add(Dense(neuron_num, input_dim=2, activity_regularizer=l1_l2(0.01, 0.01)))
model.add(Dense(neuron_num, input_dim=2))
model.add(Activation('relu'))
model.add(Dropout(0.15))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# we'll use categorical xent for the loss, and RMSprop as the optimizer
model.compile(loss='binary_crossentropy', optimizer='RMSprop')
if os.path.isfile(mlp_weight):
    model.load_weights(mlp_weight)
print("Training...")
history = model.fit(\
    df_train_inp_scaled, df_train_out, validation_data=(df_val_inp_scaled, df_val_out),callbacks=callbacks,\
    epochs=500, batch_size=10, verbose=1, shuffle=True, use_multiprocessing=True)
print('Predicting...')
# Out:
# Training...
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/500
# 1000/1000 [==============================] - 0s 436us/step - loss: 0.6099 - val_loss: 0.5953
#
# Epoch 00001: val_loss improved from inf to 0.59528, saving model to mlp_weight_ne35
# Epoch 2/500
# 1000/1000 [==============================] - 0s 288us/step - loss: 0.5840 - val_loss: 0.5786
#
# Epoch 00002: val_loss improved from 0.59528 to 0.57859, saving model to mlp_weight_ne35
# Epoch 3/500
# 1000/1000 [==============================] - 0s 284us/step - loss: 0.5639 - val_loss: 0.5648
#
# Epoch 00003: val_loss improved from 0.57859 to 0.56480, saving model to mlp_weight_ne35
# Epoch 4/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.5581 - val_loss: 0.5563
#
# Epoch 00004: val_loss improved from 0.56480 to 0.55628, saving model to mlp_weight_ne35
# Epoch 5/500
# 1000/1000 [==============================] - 0s 249us/step - loss: 0.5397 - val_loss: 0.5501
#
# Epoch 00005: val_loss improved from 0.55628 to 0.55006, saving model to mlp_weight_ne35
# Epoch 6/500
# 1000/1000 [==============================] - 0s 265us/step - loss: 0.5394 - val_loss: 0.5430
#
# Epoch 00006: val_loss improved from 0.55006 to 0.54296, saving model to mlp_weight_ne35
# Epoch 7/500
# 1000/1000 [==============================] - 0s 245us/step - loss: 0.5299 - val_loss: 0.5371
#
# Epoch 00007: val_loss improved from 0.54296 to 0.53715, saving model to mlp_weight_ne35
# Epoch 8/500
# 1000/1000 [==============================] - 0s 263us/step - loss: 0.5244 - val_loss: 0.5318
#
# Epoch 00008: val_loss improved from 0.53715 to 0.53175, saving model to mlp_weight_ne35
# Epoch 9/500
# 1000/1000 [==============================] - 0s 283us/step - loss: 0.5195 - val_loss: 0.5262
#
# Epoch 00009: val_loss improved from 0.53175 to 0.52617, saving model to mlp_weight_ne35
# Epoch 10/500
# 1000/1000 [==============================] - 0s 256us/step - loss: 0.5112 - val_loss: 0.5208
#
# Epoch 00010: val_loss improved from 0.52617 to 0.52079, saving model to mlp_weight_ne35
# Epoch 11/500
# 1000/1000 [==============================] - 0s 260us/step - loss: 0.5086 - val_loss: 0.5148
#
# Epoch 00011: val_loss improved from 0.52079 to 0.51479, saving model to mlp_weight_ne35
# Epoch 12/500
# 1000/1000 [==============================] - 0s 305us/step - loss: 0.5036 - val_loss: 0.5104
#
# Epoch 00012: val_loss improved from 0.51479 to 0.51039, saving model to mlp_weight_ne35
# Epoch 13/500
# 1000/1000 [==============================] - 0s 253us/step - loss: 0.4964 - val_loss: 0.5048
#
# Epoch 00013: val_loss improved from 0.51039 to 0.50480, saving model to mlp_weight_ne35
# Epoch 14/500
# 1000/1000 [==============================] - 0s 255us/step - loss: 0.4878 - val_loss: 0.5001
#
# Epoch 00014: val_loss improved from 0.50480 to 0.50013, saving model to mlp_weight_ne35
# Epoch 15/500
# 1000/1000 [==============================] - 0s 262us/step - loss: 0.4788 - val_loss: 0.4935
#
# Epoch 00015: val_loss improved from 0.50013 to 0.49349, saving model to mlp_weight_ne35
# Epoch 16/500
# 1000/1000 [==============================] - 0s 266us/step - loss: 0.4809 - val_loss: 0.4886
#
# Epoch 00016: val_loss improved from 0.49349 to 0.48856, saving model to mlp_weight_ne35
# Epoch 17/500
# 1000/1000 [==============================] - 0s 250us/step - loss: 0.4720 - val_loss: 0.4845
#
# Epoch 00017: val_loss improved from 0.48856 to 0.48448, saving model to mlp_weight_ne35
# Epoch 18/500
# 1000/1000 [==============================] - 0s 256us/step - loss: 0.4658 - val_loss: 0.4785
#
# Epoch 00018: val_loss improved from 0.48448 to 0.47851, saving model to mlp_weight_ne35
# Epoch 19/500
# 1000/1000 [==============================] - 0s 259us/step - loss: 0.4647 - val_loss: 0.4715
#
# Epoch 00019: val_loss improved from 0.47851 to 0.47152, saving model to mlp_weight_ne35
# Epoch 20/500
# 1000/1000 [==============================] - 0s 382us/step - loss: 0.4502 - val_loss: 0.4646
#
# Epoch 00020: val_loss improved from 0.47152 to 0.46457, saving model to mlp_weight_ne35
# Epoch 21/500
# 1000/1000 [==============================] - 0s 334us/step - loss: 0.4402 - val_loss: 0.4573
#
# Epoch 00021: val_loss improved from 0.46457 to 0.45733, saving model to mlp_weight_ne35
# Epoch 22/500
# 1000/1000 [==============================] - 0s 258us/step - loss: 0.4343 - val_loss: 0.4516
#
# Epoch 00022: val_loss improved from 0.45733 to 0.45163, saving model to mlp_weight_ne35
# Epoch 23/500
# 1000/1000 [==============================] - 0s 274us/step - loss: 0.4361 - val_loss: 0.4502
#
# Epoch 00023: val_loss improved from 0.45163 to 0.45024, saving model to mlp_weight_ne35
# Epoch 24/500
# 1000/1000 [==============================] - 0s 256us/step - loss: 0.4238 - val_loss: 0.4430
#
# Epoch 00024: val_loss improved from 0.45024 to 0.44303, saving model to mlp_weight_ne35
# Epoch 25/500
# 1000/1000 [==============================] - 0s 259us/step - loss: 0.4266 - val_loss: 0.4377
#
# Epoch 00025: val_loss improved from 0.44303 to 0.43767, saving model to mlp_weight_ne35
# Epoch 26/500
# 1000/1000 [==============================] - 0s 272us/step - loss: 0.4212 - val_loss: 0.4353
#
# Epoch 00026: val_loss improved from 0.43767 to 0.43532, saving model to mlp_weight_ne35
# Epoch 27/500
# 1000/1000 [==============================] - 0s 267us/step - loss: 0.4190 - val_loss: 0.4293
#
# Epoch 00027: val_loss improved from 0.43532 to 0.42926, saving model to mlp_weight_ne35
# Epoch 28/500
# 1000/1000 [==============================] - 0s 262us/step - loss: 0.4079 - val_loss: 0.4257
#
# Epoch 00028: val_loss improved from 0.42926 to 0.42565, saving model to mlp_weight_ne35
# Epoch 29/500
# 1000/1000 [==============================] - 0s 252us/step - loss: 0.4089 - val_loss: 0.4229
#
# Epoch 00029: val_loss improved from 0.42565 to 0.42286, saving model to mlp_weight_ne35
# Epoch 30/500
# 1000/1000 [==============================] - 0s 240us/step - loss: 0.4077 - val_loss: 0.4203
#
# Epoch 00030: val_loss improved from 0.42286 to 0.42033, saving model to mlp_weight_ne35
# Epoch 31/500
# 1000/1000 [==============================] - 0s 251us/step - loss: 0.4015 - val_loss: 0.4175
#
# Epoch 00031: val_loss improved from 0.42033 to 0.41751, saving model to mlp_weight_ne35
# Epoch 32/500
# 1000/1000 [==============================] - 0s 242us/step - loss: 0.3956 - val_loss: 0.4146
#
# Epoch 00032: val_loss improved from 0.41751 to 0.41458, saving model to mlp_weight_ne35
# Epoch 33/500
# 1000/1000 [==============================] - 0s 255us/step - loss: 0.4006 - val_loss: 0.4095
#
# Epoch 00033: val_loss improved from 0.41458 to 0.40947, saving model to mlp_weight_ne35
# Epoch 34/500
# 1000/1000 [==============================] - 0s 246us/step - loss: 0.3940 - val_loss: 0.4059
#
# Epoch 00034: val_loss improved from 0.40947 to 0.40589, saving model to mlp_weight_ne35
# Epoch 35/500
# 1000/1000 [==============================] - 0s 265us/step - loss: 0.3918 - val_loss: 0.4024
#
# Epoch 00035: val_loss improved from 0.40589 to 0.40236, saving model to mlp_weight_ne35
# Epoch 36/500
# 1000/1000 [==============================] - 0s 273us/step - loss: 0.3898 - val_loss: 0.4014
#
# Epoch 00036: val_loss improved from 0.40236 to 0.40143, saving model to mlp_weight_ne35
# Epoch 37/500
# 1000/1000 [==============================] - 0s 253us/step - loss: 0.3844 - val_loss: 0.3972
#
# Epoch 00037: val_loss improved from 0.40143 to 0.39721, saving model to mlp_weight_ne35
# Epoch 38/500
# 1000/1000 [==============================] - 0s 265us/step - loss: 0.3782 - val_loss: 0.3961
#
# Epoch 00038: val_loss improved from 0.39721 to 0.39607, saving model to mlp_weight_ne35
# Epoch 39/500
# 1000/1000 [==============================] - 0s 270us/step - loss: 0.3847 - val_loss: 0.3937
#
# Epoch 00039: val_loss improved from 0.39607 to 0.39371, saving model to mlp_weight_ne35
# Epoch 40/500
# 1000/1000 [==============================] - 0s 366us/step - loss: 0.3794 - val_loss: 0.3922
#
# Epoch 00040: val_loss improved from 0.39371 to 0.39224, saving model to mlp_weight_ne35
# Epoch 41/500
# 1000/1000 [==============================] - 0s 403us/step - loss: 0.3767 - val_loss: 0.3896
#
# Epoch 00041: val_loss improved from 0.39224 to 0.38959, saving model to mlp_weight_ne35
# Epoch 42/500
# 1000/1000 [==============================] - 0s 337us/step - loss: 0.3737 - val_loss: 0.3871
#
# Epoch 00042: val_loss improved from 0.38959 to 0.38713, saving model to mlp_weight_ne35
# Epoch 43/500
# 1000/1000 [==============================] - 0s 333us/step - loss: 0.3720 - val_loss: 0.3851
#
# Epoch 00043: val_loss improved from 0.38713 to 0.38507, saving model to mlp_weight_ne35
# Epoch 44/500
# 1000/1000 [==============================] - 0s 364us/step - loss: 0.3719 - val_loss: 0.3834
#
# Epoch 00044: val_loss improved from 0.38507 to 0.38341, saving model to mlp_weight_ne35
# Epoch 45/500
# 1000/1000 [==============================] - 0s 251us/step - loss: 0.3672 - val_loss: 0.3803
#
# Epoch 00045: val_loss improved from 0.38341 to 0.38025, saving model to mlp_weight_ne35
# Epoch 46/500
# 1000/1000 [==============================] - 0s 247us/step - loss: 0.3677 - val_loss: 0.3804
#
# Epoch 00046: val_loss did not improve from 0.38025
# Epoch 47/500
# 1000/1000 [==============================] - 0s 254us/step - loss: 0.3612 - val_loss: 0.3804
#
# Epoch 00047: val_loss did not improve from 0.38025
# Epoch 48/500
# 1000/1000 [==============================] - 0s 254us/step - loss: 0.3540 - val_loss: 0.3770
#
# Epoch 00048: val_loss improved from 0.38025 to 0.37703, saving model to mlp_weight_ne35
# Epoch 49/500
# 1000/1000 [==============================] - 0s 299us/step - loss: 0.3611 - val_loss: 0.3748
#
# Epoch 00049: val_loss improved from 0.37703 to 0.37478, saving model to mlp_weight_ne35
# Epoch 50/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.3652 - val_loss: 0.3725
#
# Epoch 00050: val_loss improved from 0.37478 to 0.37249, saving model to mlp_weight_ne35
# Epoch 51/500
# 1000/1000 [==============================] - 0s 287us/step - loss: 0.3564 - val_loss: 0.3731
#
# Epoch 00051: val_loss did not improve from 0.37249
# Epoch 52/500
# 1000/1000 [==============================] - 0s 252us/step - loss: 0.3628 - val_loss: 0.3690
#
# Epoch 00052: val_loss improved from 0.37249 to 0.36896, saving model to mlp_weight_ne35
# Epoch 53/500
# 1000/1000 [==============================] - 0s 246us/step - loss: 0.3573 - val_loss: 0.3674
#
# Epoch 00053: val_loss improved from 0.36896 to 0.36742, saving model to mlp_weight_ne35
# Epoch 54/500
# 1000/1000 [==============================] - 0s 247us/step - loss: 0.3552 - val_loss: 0.3668
#
# Epoch 00054: val_loss improved from 0.36742 to 0.36677, saving model to mlp_weight_ne35
# Epoch 55/500
# 1000/1000 [==============================] - 0s 285us/step - loss: 0.3505 - val_loss: 0.3642
#
# Epoch 00055: val_loss improved from 0.36677 to 0.36421, saving model to mlp_weight_ne35
# Epoch 56/500
# 1000/1000 [==============================] - 0s 281us/step - loss: 0.3509 - val_loss: 0.3667
#
# Epoch 00056: val_loss did not improve from 0.36421
# Epoch 57/500
# 1000/1000 [==============================] - 0s 250us/step - loss: 0.3551 - val_loss: 0.3672
#
# Epoch 00057: val_loss did not improve from 0.36421
# Epoch 58/500
# 1000/1000 [==============================] - 0s 319us/step - loss: 0.3571 - val_loss: 0.3658
#
# Epoch 00058: val_loss did not improve from 0.36421
# Epoch 59/500
# 1000/1000 [==============================] - 0s 302us/step - loss: 0.3501 - val_loss: 0.3648
#
# Epoch 00059: val_loss did not improve from 0.36421
# Epoch 60/500
# 1000/1000 [==============================] - 0s 349us/step - loss: 0.3441 - val_loss: 0.3635
#
# Epoch 00060: val_loss improved from 0.36421 to 0.36352, saving model to mlp_weight_ne35
# Epoch 61/500
# 1000/1000 [==============================] - 0s 334us/step - loss: 0.3389 - val_loss: 0.3585
#
# Epoch 00061: val_loss improved from 0.36352 to 0.35854, saving model to mlp_weight_ne35
# Epoch 62/500
# 1000/1000 [==============================] - 0s 324us/step - loss: 0.3372 - val_loss: 0.3571
#
# Epoch 00062: val_loss improved from 0.35854 to 0.35714, saving model to mlp_weight_ne35
# Epoch 63/500
# 1000/1000 [==============================] - 0s 288us/step - loss: 0.3336 - val_loss: 0.3561
#
# Epoch 00063: val_loss improved from 0.35714 to 0.35612, saving model to mlp_weight_ne35
# Epoch 64/500
# 1000/1000 [==============================] - 0s 311us/step - loss: 0.3443 - val_loss: 0.3560
#
# Epoch 00064: val_loss improved from 0.35612 to 0.35601, saving model to mlp_weight_ne35
# Epoch 65/500
# 1000/1000 [==============================] - 0s 333us/step - loss: 0.3467 - val_loss: 0.3544
#
# Epoch 00065: val_loss improved from 0.35601 to 0.35436, saving model to mlp_weight_ne35
# Epoch 66/500
# 1000/1000 [==============================] - 0s 277us/step - loss: 0.3430 - val_loss: 0.3537
#
# Epoch 00066: val_loss improved from 0.35436 to 0.35368, saving model to mlp_weight_ne35
# Epoch 67/500
# 1000/1000 [==============================] - 0s 270us/step - loss: 0.3352 - val_loss: 0.3544
#
# Epoch 00067: val_loss did not improve from 0.35368
# Epoch 68/500
# 1000/1000 [==============================] - 0s 326us/step - loss: 0.3450 - val_loss: 0.3557
#
# Epoch 00068: val_loss did not improve from 0.35368
# Epoch 69/500
# 1000/1000 [==============================] - 0s 265us/step - loss: 0.3407 - val_loss: 0.3556
#
# Epoch 00069: val_loss did not improve from 0.35368
# Epoch 70/500
# 1000/1000 [==============================] - 0s 253us/step - loss: 0.3338 - val_loss: 0.3523
#
# Epoch 00070: val_loss improved from 0.35368 to 0.35233, saving model to mlp_weight_ne35
# Epoch 71/500
# 1000/1000 [==============================] - 0s 248us/step - loss: 0.3424 - val_loss: 0.3547
#
# Epoch 00071: val_loss did not improve from 0.35233
# Epoch 72/500
# 1000/1000 [==============================] - 0s 289us/step - loss: 0.3438 - val_loss: 0.3536
#
# Epoch 00072: val_loss did not improve from 0.35233
# Epoch 73/500
# 1000/1000 [==============================] - 0s 273us/step - loss: 0.3424 - val_loss: 0.3525
#
# Epoch 00073: val_loss did not improve from 0.35233
# Epoch 74/500
# 1000/1000 [==============================] - 0s 386us/step - loss: 0.3294 - val_loss: 0.3485
#
# Epoch 00074: val_loss improved from 0.35233 to 0.34850, saving model to mlp_weight_ne35
# Epoch 75/500
# 1000/1000 [==============================] - 0s 277us/step - loss: 0.3401 - val_loss: 0.3501
#
# Epoch 00075: val_loss did not improve from 0.34850
# Epoch 76/500
# 1000/1000 [==============================] - 0s 299us/step - loss: 0.3373 - val_loss: 0.3499
#
# Epoch 00076: val_loss did not improve from 0.34850
# Epoch 77/500
# 1000/1000 [==============================] - 0s 267us/step - loss: 0.3359 - val_loss: 0.3490
#
# Epoch 00077: val_loss did not improve from 0.34850
# Epoch 78/500
# 1000/1000 [==============================] - 0s 256us/step - loss: 0.3440 - val_loss: 0.3505
#
# Epoch 00078: val_loss did not improve from 0.34850
# Epoch 79/500
# 1000/1000 [==============================] - 0s 348us/step - loss: 0.3293 - val_loss: 0.3500
#
# Epoch 00079: val_loss did not improve from 0.34850
# Epoch 80/500
# 1000/1000 [==============================] - 0s 262us/step - loss: 0.3413 - val_loss: 0.3493
#
# Epoch 00080: val_loss did not improve from 0.34850
# Epoch 81/500
# 1000/1000 [==============================] - 0s 319us/step - loss: 0.3274 - val_loss: 0.3467
#
# Epoch 00081: val_loss improved from 0.34850 to 0.34672, saving model to mlp_weight_ne35
# Epoch 82/500
# 1000/1000 [==============================] - 0s 383us/step - loss: 0.3381 - val_loss: 0.3498
#
# Epoch 00082: val_loss did not improve from 0.34672
# Epoch 83/500
# 1000/1000 [==============================] - 0s 350us/step - loss: 0.3305 - val_loss: 0.3492
#
# Epoch 00083: val_loss did not improve from 0.34672
# Epoch 84/500
# 1000/1000 [==============================] - 0s 320us/step - loss: 0.3294 - val_loss: 0.3476
#
# Epoch 00084: val_loss did not improve from 0.34672
# Epoch 85/500
# 1000/1000 [==============================] - 0s 310us/step - loss: 0.3413 - val_loss: 0.3467
#
# Epoch 00085: val_loss did not improve from 0.34672
# Epoch 86/500
# 1000/1000 [==============================] - 0s 279us/step - loss: 0.3224 - val_loss: 0.3477
#
# Epoch 00086: val_loss did not improve from 0.34672
# Epoch 87/500
# 1000/1000 [==============================] - 0s 301us/step - loss: 0.3333 - val_loss: 0.3469
#
# Epoch 00087: val_loss did not improve from 0.34672
# Epoch 88/500
# 1000/1000 [==============================] - 0s 299us/step - loss: 0.3345 - val_loss: 0.3456
#
# Epoch 00088: val_loss improved from 0.34672 to 0.34556, saving model to mlp_weight_ne35
# Epoch 89/500
# 1000/1000 [==============================] - 0s 306us/step - loss: 0.3281 - val_loss: 0.3460
#
# Epoch 00089: val_loss did not improve from 0.34556
# Epoch 90/500
# 1000/1000 [==============================] - 0s 243us/step - loss: 0.3231 - val_loss: 0.3459
#
# Epoch 00090: val_loss did not improve from 0.34556
# Epoch 91/500
# 1000/1000 [==============================] - 0s 259us/step - loss: 0.3274 - val_loss: 0.3457
#
# Epoch 00091: val_loss did not improve from 0.34556
# Epoch 92/500
# 1000/1000 [==============================] - 0s 349us/step - loss: 0.3379 - val_loss: 0.3476
#
# Epoch 00092: val_loss did not improve from 0.34556
# Epoch 93/500
# 1000/1000 [==============================] - 0s 278us/step - loss: 0.3213 - val_loss: 0.3463
#
# Epoch 00093: val_loss did not improve from 0.34556
# Epoch 94/500
# 1000/1000 [==============================] - 0s 263us/step - loss: 0.3241 - val_loss: 0.3435
#
# Epoch 00094: val_loss improved from 0.34556 to 0.34354, saving model to mlp_weight_ne35
# Epoch 95/500
# 1000/1000 [==============================] - 0s 436us/step - loss: 0.3284 - val_loss: 0.3419
#
# Epoch 00095: val_loss improved from 0.34354 to 0.34192, saving model to mlp_weight_ne35
# Epoch 96/500
# 1000/1000 [==============================] - 0s 322us/step - loss: 0.3324 - val_loss: 0.3410
#
# Epoch 00096: val_loss improved from 0.34192 to 0.34100, saving model to mlp_weight_ne35
# Epoch 97/500
# 1000/1000 [==============================] - 0s 281us/step - loss: 0.3446 - val_loss: 0.3441
#
# Epoch 00097: val_loss did not improve from 0.34100
# Epoch 98/500
# 1000/1000 [==============================] - 0s 327us/step - loss: 0.3227 - val_loss: 0.3455
#
# Epoch 00098: val_loss did not improve from 0.34100
# Epoch 99/500
# 1000/1000 [==============================] - 0s 297us/step - loss: 0.3305 - val_loss: 0.3440
#
# Epoch 00099: val_loss did not improve from 0.34100
# Epoch 100/500
# 1000/1000 [==============================] - 0s 251us/step - loss: 0.3324 - val_loss: 0.3482
#
# Epoch 00100: val_loss did not improve from 0.34100
# Epoch 101/500
# 1000/1000 [==============================] - 0s 245us/step - loss: 0.3220 - val_loss: 0.3463
#
# Epoch 00101: val_loss did not improve from 0.34100
# Epoch 102/500
# 1000/1000 [==============================] - 0s 284us/step - loss: 0.3291 - val_loss: 0.3435
#
# Epoch 00102: val_loss did not improve from 0.34100
# Epoch 103/500
# 1000/1000 [==============================] - 0s 271us/step - loss: 0.3285 - val_loss: 0.3516
#
# Epoch 00103: val_loss did not improve from 0.34100
# Epoch 104/500
# 1000/1000 [==============================] - 0s 285us/step - loss: 0.3222 - val_loss: 0.3446
#
# Epoch 00104: val_loss did not improve from 0.34100
# Epoch 105/500
# 1000/1000 [==============================] - 0s 296us/step - loss: 0.3214 - val_loss: 0.3462
#
# Epoch 00105: val_loss did not improve from 0.34100
# Epoch 106/500
# 1000/1000 [==============================] - 0s 354us/step - loss: 0.3333 - val_loss: 0.3460
#
# Epoch 00106: val_loss did not improve from 0.34100
# Epoch 107/500
# 1000/1000 [==============================] - 0s 288us/step - loss: 0.3269 - val_loss: 0.3441
#
# Epoch 00107: val_loss did not improve from 0.34100
# Epoch 108/500
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.3315 - val_loss: 0.3453
#
# Epoch 00108: val_loss did not improve from 0.34100
# Epoch 109/500
# 1000/1000 [==============================] - 0s 474us/step - loss: 0.3244 - val_loss: 0.3410
#
# Epoch 00109: val_loss improved from 0.34100 to 0.34098, saving model to mlp_weight_ne35
# Epoch 110/500
# 1000/1000 [==============================] - 0s 281us/step - loss: 0.3186 - val_loss: 0.3415
#
# Epoch 00110: val_loss did not improve from 0.34098
# Epoch 111/500
# 1000/1000 [==============================] - 0s 341us/step - loss: 0.3352 - val_loss: 0.3454
#
# Epoch 00111: val_loss did not improve from 0.34098
# Epoch 112/500
# 1000/1000 [==============================] - 0s 333us/step - loss: 0.3281 - val_loss: 0.3441
#
# Epoch 00112: val_loss did not improve from 0.34098
# Epoch 113/500
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.3232 - val_loss: 0.3465
#
# Epoch 00113: val_loss did not improve from 0.34098
# Epoch 114/500
# 1000/1000 [==============================] - 0s 378us/step - loss: 0.3162 - val_loss: 0.3475
#
# Epoch 00114: val_loss did not improve from 0.34098
# Epoch 115/500
# 1000/1000 [==============================] - 0s 425us/step - loss: 0.3211 - val_loss: 0.3430
#
# Epoch 00115: val_loss did not improve from 0.34098
# Epoch 116/500
# 1000/1000 [==============================] - 0s 438us/step - loss: 0.3220 - val_loss: 0.3427
#
# Epoch 00116: val_loss did not improve from 0.34098
# Epoch 117/500
# 1000/1000 [==============================] - 0s 389us/step - loss: 0.3348 - val_loss: 0.3442
#
# Epoch 00117: val_loss did not improve from 0.34098
# Epoch 118/500
# 1000/1000 [==============================] - 0s 275us/step - loss: 0.3250 - val_loss: 0.3479
#
# Epoch 00118: val_loss did not improve from 0.34098
# Epoch 119/500
# 1000/1000 [==============================] - 0s 360us/step - loss: 0.3166 - val_loss: 0.3404
#
# Epoch 00119: val_loss improved from 0.34098 to 0.34042, saving model to mlp_weight_ne35
# Epoch 120/500
# 1000/1000 [==============================] - 0s 318us/step - loss: 0.3260 - val_loss: 0.3397
#
# Epoch 00120: val_loss improved from 0.34042 to 0.33971, saving model to mlp_weight_ne35
# Epoch 121/500
# 1000/1000 [==============================] - 0s 305us/step - loss: 0.3185 - val_loss: 0.3399
#
# Epoch 00121: val_loss did not improve from 0.33971
# Epoch 122/500
# 1000/1000 [==============================] - 0s 236us/step - loss: 0.3258 - val_loss: 0.3433
#
# Epoch 00122: val_loss did not improve from 0.33971
# Epoch 123/500
# 1000/1000 [==============================] - 0s 237us/step - loss: 0.3238 - val_loss: 0.3444
#
# Epoch 00123: val_loss did not improve from 0.33971
# Epoch 124/500
# 1000/1000 [==============================] - 0s 243us/step - loss: 0.3256 - val_loss: 0.3427
#
# Epoch 00124: val_loss did not improve from 0.33971
# Epoch 125/500
# 1000/1000 [==============================] - 0s 360us/step - loss: 0.3227 - val_loss: 0.3407
#
# Epoch 00125: val_loss did not improve from 0.33971
# Epoch 126/500
# 1000/1000 [==============================] - 0s 258us/step - loss: 0.3184 - val_loss: 0.3422
#
# Epoch 00126: val_loss did not improve from 0.33971
# Epoch 127/500
# 1000/1000 [==============================] - 0s 253us/step - loss: 0.3208 - val_loss: 0.3426
#
# Epoch 00127: val_loss did not improve from 0.33971
# Epoch 128/500
# 1000/1000 [==============================] - 0s 245us/step - loss: 0.3210 - val_loss: 0.3448
#
# Epoch 00128: val_loss did not improve from 0.33971
# Epoch 129/500
# 1000/1000 [==============================] - 0s 255us/step - loss: 0.3229 - val_loss: 0.3422
#
# Epoch 00129: val_loss did not improve from 0.33971
# Epoch 130/500
# 1000/1000 [==============================] - 0s 254us/step - loss: 0.3225 - val_loss: 0.3424
#
# Epoch 00130: val_loss did not improve from 0.33971
# Epoch 131/500
# 1000/1000 [==============================] - 0s 305us/step - loss: 0.3276 - val_loss: 0.3402
#
# Epoch 00131: val_loss did not improve from 0.33971
# Epoch 132/500
# 1000/1000 [==============================] - 0s 272us/step - loss: 0.3293 - val_loss: 0.3422
#
# Epoch 00132: val_loss did not improve from 0.33971
# Epoch 133/500
# 1000/1000 [==============================] - 0s 301us/step - loss: 0.3265 - val_loss: 0.3404
#
# Epoch 00133: val_loss did not improve from 0.33971
# Epoch 134/500
# 1000/1000 [==============================] - 0s 346us/step - loss: 0.3243 - val_loss: 0.3463
#
# Epoch 00134: val_loss did not improve from 0.33971
# Epoch 135/500
# 1000/1000 [==============================] - 0s 290us/step - loss: 0.3125 - val_loss: 0.3406
#
# Epoch 00135: val_loss did not improve from 0.33971
# Epoch 136/500
# 1000/1000 [==============================] - 0s 302us/step - loss: 0.3290 - val_loss: 0.3445
#
# Epoch 00136: val_loss did not improve from 0.33971
# Epoch 137/500
# 1000/1000 [==============================] - 0s 279us/step - loss: 0.3256 - val_loss: 0.3419
#
# Epoch 00137: val_loss did not improve from 0.33971
# Epoch 138/500
# 1000/1000 [==============================] - 0s 244us/step - loss: 0.3305 - val_loss: 0.3399
#
# Epoch 00138: val_loss did not improve from 0.33971
# Epoch 139/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.3130 - val_loss: 0.3435
#
# Epoch 00139: val_loss did not improve from 0.33971
# Epoch 140/500
# 1000/1000 [==============================] - 0s 256us/step - loss: 0.3262 - val_loss: 0.3441
#
# Epoch 00140: val_loss did not improve from 0.33971
# Epoch 141/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3289 - val_loss: 0.3424
#
# Epoch 00141: val_loss did not improve from 0.33971
# Epoch 142/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3184 - val_loss: 0.3451
#
# Epoch 00142: val_loss did not improve from 0.33971
# Epoch 143/500
# 1000/1000 [==============================] - 0s 258us/step - loss: 0.3281 - val_loss: 0.3480
#
# Epoch 00143: val_loss did not improve from 0.33971
# Epoch 144/500
# 1000/1000 [==============================] - 0s 246us/step - loss: 0.3310 - val_loss: 0.3440
#
# Epoch 00144: val_loss did not improve from 0.33971
# Epoch 145/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.3252 - val_loss: 0.3421
#
# Epoch 00145: val_loss did not improve from 0.33971
# Epoch 146/500
# 1000/1000 [==============================] - 0s 275us/step - loss: 0.3100 - val_loss: 0.3391
#
# Epoch 00146: val_loss improved from 0.33971 to 0.33914, saving model to mlp_weight_ne35
# Epoch 147/500
# 1000/1000 [==============================] - 0s 264us/step - loss: 0.3286 - val_loss: 0.3415
#
# Epoch 00147: val_loss did not improve from 0.33914
# Epoch 148/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3334 - val_loss: 0.3429
#
# Epoch 00148: val_loss did not improve from 0.33914
# Epoch 149/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.3144 - val_loss: 0.3463
#
# Epoch 00149: val_loss did not improve from 0.33914
# Epoch 150/500
# 1000/1000 [==============================] - 0s 262us/step - loss: 0.3346 - val_loss: 0.3430
#
# Epoch 00150: val_loss did not improve from 0.33914
# Epoch 151/500
# 1000/1000 [==============================] - 0s 254us/step - loss: 0.3144 - val_loss: 0.3404
#
# Epoch 00151: val_loss did not improve from 0.33914
# Epoch 152/500
# 1000/1000 [==============================] - 0s 232us/step - loss: 0.3265 - val_loss: 0.3437
#
# Epoch 00152: val_loss did not improve from 0.33914
# Epoch 153/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3438 - val_loss: 0.3457
#
# Epoch 00153: val_loss did not improve from 0.33914
# Epoch 154/500
# 1000/1000 [==============================] - 0s 236us/step - loss: 0.3233 - val_loss: 0.3425
#
# Epoch 00154: val_loss did not improve from 0.33914
# Epoch 155/500
# 1000/1000 [==============================] - 0s 245us/step - loss: 0.3187 - val_loss: 0.3454
#
# Epoch 00155: val_loss did not improve from 0.33914
# Epoch 156/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3103 - val_loss: 0.3443
#
# Epoch 00156: val_loss did not improve from 0.33914
# Epoch 157/500
# 1000/1000 [==============================] - 0s 311us/step - loss: 0.3293 - val_loss: 0.3415
#
# Epoch 00157: val_loss did not improve from 0.33914
# Epoch 158/500
# 1000/1000 [==============================] - 0s 377us/step - loss: 0.3292 - val_loss: 0.3468
#
# Epoch 00158: val_loss did not improve from 0.33914
# Epoch 159/500
# 1000/1000 [==============================] - 0s 284us/step - loss: 0.3313 - val_loss: 0.3415
#
# Epoch 00159: val_loss did not improve from 0.33914
# Epoch 160/500
# 1000/1000 [==============================] - 0s 275us/step - loss: 0.3432 - val_loss: 0.3426
#
# Epoch 00160: val_loss did not improve from 0.33914
# Epoch 161/500
# 1000/1000 [==============================] - 0s 258us/step - loss: 0.3217 - val_loss: 0.3417
#
# Epoch 00161: val_loss did not improve from 0.33914
# Epoch 162/500
# 1000/1000 [==============================] - 0s 253us/step - loss: 0.3174 - val_loss: 0.3418
#
# Epoch 00162: val_loss did not improve from 0.33914
# Epoch 163/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3132 - val_loss: 0.3457
#
# Epoch 00163: val_loss did not improve from 0.33914
# Epoch 164/500
# 1000/1000 [==============================] - 0s 240us/step - loss: 0.3152 - val_loss: 0.3418
#
# Epoch 00164: val_loss did not improve from 0.33914
# Epoch 165/500
# 1000/1000 [==============================] - 0s 231us/step - loss: 0.3178 - val_loss: 0.3430
#
# Epoch 00165: val_loss did not improve from 0.33914
# Epoch 166/500
# 1000/1000 [==============================] - 0s 221us/step - loss: 0.3325 - val_loss: 0.3433
#
# Epoch 00166: val_loss did not improve from 0.33914
# Epoch 167/500
# 1000/1000 [==============================] - 0s 246us/step - loss: 0.3299 - val_loss: 0.3426
#
# Epoch 00167: val_loss did not improve from 0.33914
# Epoch 168/500
# 1000/1000 [==============================] - 0s 233us/step - loss: 0.3268 - val_loss: 0.3440
#
# Epoch 00168: val_loss did not improve from 0.33914
# Epoch 169/500
# 1000/1000 [==============================] - 0s 264us/step - loss: 0.3192 - val_loss: 0.3452
#
# Epoch 00169: val_loss did not improve from 0.33914
# Epoch 170/500
# 1000/1000 [==============================] - 0s 261us/step - loss: 0.3155 - val_loss: 0.3435
#
# Epoch 00170: val_loss did not improve from 0.33914
# Epoch 171/500
# 1000/1000 [==============================] - 0s 250us/step - loss: 0.3105 - val_loss: 0.3423
#
# Epoch 00171: val_loss did not improve from 0.33914
# Epoch 172/500
# 1000/1000 [==============================] - 0s 238us/step - loss: 0.3151 - val_loss: 0.3444
#
# Epoch 00172: val_loss did not improve from 0.33914
# Epoch 173/500
# 1000/1000 [==============================] - 0s 292us/step - loss: 0.3201 - val_loss: 0.3439
#
# Epoch 00173: val_loss did not improve from 0.33914
# Epoch 174/500
# 1000/1000 [==============================] - 0s 384us/step - loss: 0.3264 - val_loss: 0.3432
#
# Epoch 00174: val_loss did not improve from 0.33914
# Epoch 175/500
# 1000/1000 [==============================] - 0s 321us/step - loss: 0.3196 - val_loss: 0.3438
#
# Epoch 00175: val_loss did not improve from 0.33914
# Epoch 176/500
# 1000/1000 [==============================] - 0s 335us/step - loss: 0.3244 - val_loss: 0.3417
#
# Epoch 00176: val_loss did not improve from 0.33914
# Epoch 177/500
# 1000/1000 [==============================] - 0s 263us/step - loss: 0.3237 - val_loss: 0.3431
#
# Epoch 00177: val_loss did not improve from 0.33914
# Epoch 178/500
# 1000/1000 [==============================] - 0s 281us/step - loss: 0.3233 - val_loss: 0.3425
#
# Epoch 00178: val_loss did not improve from 0.33914
# Epoch 179/500
# 1000/1000 [==============================] - 0s 251us/step - loss: 0.3121 - val_loss: 0.3440
#
# Epoch 00179: val_loss did not improve from 0.33914
# Epoch 180/500
# 1000/1000 [==============================] - 0s 263us/step - loss: 0.3273 - val_loss: 0.3430
#
# Epoch 00180: val_loss did not improve from 0.33914
# Epoch 181/500
# 1000/1000 [==============================] - 0s 233us/step - loss: 0.3272 - val_loss: 0.3437
#
# Epoch 00181: val_loss did not improve from 0.33914
# Epoch 182/500
# 1000/1000 [==============================] - 0s 242us/step - loss: 0.3213 - val_loss: 0.3471
#
# Epoch 00182: val_loss did not improve from 0.33914
# Epoch 183/500
# 1000/1000 [==============================] - 0s 243us/step - loss: 0.3179 - val_loss: 0.3405
#
# Epoch 00183: val_loss did not improve from 0.33914
# Epoch 184/500
# 1000/1000 [==============================] - 0s 226us/step - loss: 0.3329 - val_loss: 0.3446
#
# Epoch 00184: val_loss did not improve from 0.33914
# Epoch 185/500
# 1000/1000 [==============================] - 0s 239us/step - loss: 0.3124 - val_loss: 0.3442
#
# Epoch 00185: val_loss did not improve from 0.33914
# Epoch 186/500
# 1000/1000 [==============================] - 0s 233us/step - loss: 0.3142 - val_loss: 0.3436
#
# Epoch 00186: val_loss did not improve from 0.33914
# Epoch 187/500
# 1000/1000 [==============================] - 0s 232us/step - loss: 0.3236 - val_loss: 0.3436
#
# Epoch 00187: val_loss did not improve from 0.33914
# Epoch 188/500
# 1000/1000 [==============================] - 0s 241us/step - loss: 0.3235 - val_loss: 0.3419
#
# Epoch 00188: val_loss did not improve from 0.33914
# Epoch 189/500
# 1000/1000 [==============================] - 0s 245us/step - loss: 0.3244 - val_loss: 0.3445
#
# Epoch 00189: val_loss did not improve from 0.33914
# Epoch 190/500
# 1000/1000 [==============================] - 0s 224us/step - loss: 0.3188 - val_loss: 0.3425
#
# Epoch 00190: val_loss did not improve from 0.33914
# Epoch 191/500
# 1000/1000 [==============================] - 0s 249us/step - loss: 0.3237 - val_loss: 0.3413
#
# Epoch 00191: val_loss did not improve from 0.33914
# Epoch 192/500
# 1000/1000 [==============================] - 0s 236us/step - loss: 0.3147 - val_loss: 0.3441
#
# Epoch 00192: val_loss did not improve from 0.33914
# Epoch 193/500
# 1000/1000 [==============================] - 0s 233us/step - loss: 0.3135 - val_loss: 0.3413
#
# Epoch 00193: val_loss did not improve from 0.33914
# Epoch 194/500
# 1000/1000 [==============================] - 0s 240us/step - loss: 0.3063 - val_loss: 0.3443
#
# Epoch 00194: val_loss did not improve from 0.33914
# Epoch 195/500
# 1000/1000 [==============================] - 0s 235us/step - loss: 0.3144 - val_loss: 0.3463
#
# Epoch 00195: val_loss did not improve from 0.33914
# Epoch 196/500
# 1000/1000 [==============================] - 0s 237us/step - loss: 0.3150 - val_loss: 0.3445
#
# Epoch 00196: val_loss did not improve from 0.33914
# Epoch 197/500
# 1000/1000 [==============================] - 0s 240us/step - loss: 0.3247 - val_loss: 0.3430
#
# Epoch 00197: val_loss did not improve from 0.33914
# Epoch 198/500
# 1000/1000 [==============================] - 0s 232us/step - loss: 0.3208 - val_loss: 0.3442
#
# Epoch 00198: val_loss did not improve from 0.33914
# Epoch 199/500
# 1000/1000 [==============================] - 0s 233us/step - loss: 0.3163 - val_loss: 0.3447
#
# Epoch 00199: val_loss did not improve from 0.33914
# Epoch 200/500
# 1000/1000 [==============================] - 0s 237us/step - loss: 0.3225 - val_loss: 0.3459
#
# Epoch 00200: val_loss did not improve from 0.33914
# Epoch 00200: early stopping
# Predicting...

# %%
# Região decisão dados de treino !
h = 0.1
x1_min, x1_max = df_train_inp_scaled['x1'].min(), df_train_inp_scaled['x1'].max()
x2_min, x2_max = df_train_inp_scaled['x2'].min(), df_train_inp_scaled['x2'].max()
 
xx, yy = np.meshgrid(
    np.arange(x1_min, x1_max, h),
    np.arange(x2_min, x2_max, h))

Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx,yy,Z,colors=['red','red','red','red','red','red','blue'], alpha=0.8)
plt.savefig('mpl_decision.png')

# %%
preds = model.predict(df_test_inp_scaled, verbose=1)
class_pred = model.predict_classes(df_test_inp_scaled, verbose=1)

plot_history(history)
plot_roc(df_val_out, model.predict(df_val_inp_scaled, verbose=1))
print(classification_report(\
    df_test_out.to_numpy(), class_pred))
# Out:
# 1000/1000 [==============================] - 0s 22us/step
# 1000/1000 [==============================] - 0s 16us/step
# 1000/1000 [==============================] - 0s 20us/step
# ROC Score 0.9272870024315111
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88       499
#          1.0       0.89      0.85      0.87       501
#
#     accuracy                           0.87      1000
#    macro avg       0.87      0.87      0.87      1000
# weighted avg       0.87      0.87      0.87      1000

# %%
df_train_inp_scaled
# Out:
#            x1        x2
# 0    0.626865  0.017208
# 1    1.047823  0.627189
# 2    0.512837  1.048167
# 3   -0.387538  0.513155
# 4    1.212552 -0.387262
# ..        ...       ...
# 995  1.642612 -0.674162
# 996  1.682465  1.642985
# 997  0.468711  1.682840
# 998 -0.225447  0.469028
# 999  0.310821 -0.225164
#
# [1000 rows x 2 columns]

# %%
## Teste para múltiplos neurônios
# MLP
fig = plt.figure(figsize=(10,5))
plt.grid(color='#919191', linestyle=':', linewidth=1)
plt.title('Curva ROC')
plt.xlabel('FP')
plt.ylabel('TP')
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.05])
plt.plot([0, 1], [0, 1], color='red', lw=1, linestyle='--', label='Decisão aleatória')

mlp_weight = 'mlp_weight_ne'+str(neuron_num)
callbacks = [
    EarlyStopping(monitor='val_loss', \
        min_delta=0.01, patience=200, verbose=1,\
        mode='min', baseline=0.001, restore_best_weights=False),
    ModelCheckpoint('mlp_test', monitor='val_loss', save_best_only=True, verbose=0)
]

for neuron_num in range(5, 66, 10):
    model = Sequential()
    # model.add(Dense(neuron_num, input_dim=2, activity_regularizer=l1_l2(0.01, 0.01)))
    model.add(Dense(neuron_num, input_dim=2))
    model.add(Activation('relu'))
    model.add(Dropout(0.15))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    # we'll use categorical xent for the loss, and RMSprop as the optimizer
    model.compile(loss='binary_crossentropy', optimizer='RMSprop')
    if os.path.isfile('mlp_test'):
        model.load_weights('mlp_test')
        
    print("Training... {}".format(neuron_num))
    history = model.fit(\
        df_train_inp_scaled, df_train_out, validation_data=(df_val_inp_scaled, df_val_out),callbacks=callbacks,\
        epochs=500, batch_size=10, verbose=0, shuffle=True, use_multiprocessing=True)
    print('Predicting...')
    preds = model.predict(df_test_inp_scaled, verbose=1)
    roc_score = roc_auc_score(df_test_out, preds)
    print("ROC Score", roc_score)
    # Results ROC
    fpr, tpr, thresholds = roc_curve(df_test_out, preds)
    roc_score = roc_auc_score(df_test_out, preds)
    plt.plot(fpr, tpr, label='MPL neuron_num={0} roc_score={1:.4}'.format(neuron_num, roc_score))
    if os.path.isfile('mlp_test'):
        os.remove('mlp_test')
plt.grid(True)
plt.legend()
plt.show()
fig.savefig('mlp_roc_multi.png', dpi=600)
print("ROC Score", roc_score)
# Out:
# Training... 5
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 33us/step
# ROC Score 0.8787555150220601
# Training... 15
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 41us/step
# ROC Score 0.9302877211508845
# Training... 25
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 40us/step
# ROC Score 0.9341997367989473
# Training... 35
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 34us/step
# ROC Score 0.9362437449749799
# Training... 45
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 31us/step
# ROC Score 0.937559750239001
# Training... 55
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 31us/step
# ROC Score 0.9392677570710283
# Training... 65
# Epoch 00200: early stopping
# Predicting...
# 1000/1000 [==============================] - 0s 30us/step
# ROC Score 0.9364277457109829
# ROC Score 0.9364277457109829

# %%
classification_report( df_test_out.to_numpy(), class_pred, output_dict=True)['accuracy']
# Out:
# 0.873
