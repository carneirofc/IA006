# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas
import utils as utils
import numpy as np
import math
from sklearn.metrics import confusion_matrix

# %%
data = utils.load_data('dados_voz_genero.csv')

# %%
data.hist(figsize=(30,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5ddf9f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58992b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5894ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f588feb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5892ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f588eba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58898e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58857ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58860690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58812fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58785e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5873ab10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f586faed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5872eb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f586edf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f586a3b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58663f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f58617bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f585d7f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1f5858bc10>]],
#       dtype=object)

# %%
corr = data.corr().style.background_gradient(cmap='coolwarm')
corr
# Out:
# <style  type="text/css" >
#     #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col4 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col5 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col6 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col7 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col8 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col10 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col11 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col12 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col13 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col18 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow0_col19 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col2 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col3 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col7 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col9 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col10 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col11 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col12 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col13 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col14 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col15 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col16 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col17 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col18 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow1_col19 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col1 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col3 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col6 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col9 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col10 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col11 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col12 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col13 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col14 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col16 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col17 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col18 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_bcebd804_e874_11e9_82e8_702c1f11c49brow2_col19 {
#             background-color:  #7396f5;

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, figsize=(35, 35))
plt.show()
